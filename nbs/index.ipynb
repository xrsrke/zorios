# %%
#| hide
from zorios.core import *
from zorios.universe import BuildUniverse
from zorios.object import Particle

# %% [markdown]
# # zorios
#
# > A physics simulation framework

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install zorios
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %% [markdown]
# ![image.png](attachment:21335b86-7b52-48de-8e31-986e2373b9ad.png)

# %%
universe = BuildUniverse().setEarthGravity(True).build()

# %%
universe.__dict__
# Out:
# {'is_earth_gravity': True}

# %%
bottle = Particle()
